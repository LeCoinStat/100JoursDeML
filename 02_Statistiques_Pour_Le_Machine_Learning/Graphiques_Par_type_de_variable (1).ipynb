# %% [markdown]
# # Importation des packages

# %%
import pandas as pd
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Chargement des données

# %%
# Chargement des données
titanic=sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %% [markdown]
# # Graphiques adaptés pour les variables qualitatives

# %% [markdown]
# ## Graphiques adaptés pour les variables nominales

# %% [markdown]
# ### Diagramme en barres

# %%
# Graphique en barres pour la fréquence de chaque catégorie
plt.figure(figsize=(8,6)) # <--- Définir la taille du cadre
ax = sns.countplot(x="species", data=iris)
plt.title("Nombre de fleurs par catégorie")

# Ajouter le nombre de chaque catégorie sur les barres
for p in ax.patches:
    ax.annotate(format(p.get_height(), ".0f"), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %%
# Calculer la proportion de chaque catégorie
prop_df = iris["species"].value_counts(normalize=True).reset_index()
prop_df.columns = ["species", "proportion"]

plt.figure(figsize=(8,6)) # <--- Définir la taille du cadre
ax = sns.barplot(x="species", y="proportion", data=prop_df)

# Ajouter les proportions sur les barres
for p in ax.patches:
    ax.annotate(format(p.get_height(), ".2%"), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %%
# Graphique en barres pour la proportion de chaque catégorie
# Calculer la proportion de chaque catégorie
prop_df = iris["species"].value_counts(normalize=True).reset_index()
prop_df.columns = ["species", "proportion"]

# Graphique en barres pour la fréquence de chaque catégorie
plt.figure(figsize=(8,6))
ax = sns.countplot(x="species", data=iris)
plt.title("Nombre de fleurs par catégorie")

# Ajouter le nombre et la proportion de chaque catégorie sur les barres
for p, prop, count in zip(ax.patches, prop_df["proportion"], iris["species"].value_counts().sort_index()):
    ax.annotate(f'({count}, {prop:.0%})', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %% [markdown]
# ### Cammemberg, Graphique en secteurs ou pie chart

# %%
# Calculer la proportion et le nombre de chaque catégorie
# Calculer la proportion de chaque catégorie
prop_df = iris["species"].value_counts(normalize=True).reset_index()
prop_df.columns = ["species", "proportion"]

# Graphique en secteurs pour la fréquence de chaque catégorie
plt.figure(figsize=(8,6))
ax = iris["species"].value_counts().plot(kind="pie", autopct=lambda x: f'{x:.0f}% ({x/100*len(iris):.0f})')

# Ajouter le titre
plt.title("Nombre et proportion de fleurs par catégorie")

plt.show()

# %% [markdown]
# ## Diagrammes adaptés pour les variables qualitative ordinales

# %%
# Créer une variable qualitative ordinale
ordinal_var = tips["size"]

# %% [markdown]
# ###  Diagramme en bâton

# %%
prop_df = tips["size"].value_counts(normalize=True).reset_index()
prop_df.columns = ["size", "proportion"]


# Graphique en barres pour la fréquence de chaque catégorie
plt.figure(figsize=(8,6))
ax = sns.countplot(x="size", data=tips)
plt.title("Nombre et proportion de clients par taille de groupe")


# Ajouter le nombre et la proportion de chaque catégorie sur les barres
for p, prop, count in zip(ax.patches, prop_df["proportion"], tips["size"].value_counts().sort_index()):
    ax.annotate(f'({count}, {prop:.0%})', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %% [markdown]
# ### Pie chart

# %%
# Vous pouvez faire un boxplot seulement si la variable entre 3 et 7 modalités maximum

# Calculer la proportion de chaque catégorie
prop_df = tips["size"].value_counts(normalize=True).reset_index()
prop_df.columns = ["size", "proportion"]

# Graphique en secteurs pour la fréquence de chaque catégorie
plt.figure(figsize=(8,6))
ax = tips["size"].value_counts().plot(kind="pie", autopct=lambda x: f'{x:.0f}% ({x/100*len(iris):.0f})')

# Ajouter le titre
plt.title("Nombre et proportion de clients par taille de groupe")

plt.show()

# %% [markdown]
# # Graphiques adaptés pour les variables continues

# %% [markdown]
# ## Graphiques adaptés pour les variables discrètes

# %% [markdown]
# ### Histogramme

# %%
# Créer une variable quantitative discrète
age_var = titanic["age"].dropna().astype(int)

# Histogramme
sns.histplot(x=age_var, discrete=True)
plt.title("Distribution des âges sur le Titanic")
plt.xlabel("Âge")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# ### Boxplot

# %%
# Box plot
sns.boxplot(x=age_var)
plt.title("Distribution des âges sur le Titanic")
plt.xlabel("Âge")
plt.show()

# %% [markdown]
# ## Graphique adaptés pour les variables continues

# %% [markdown]
# ### Histogramme

# %%
# Créer une variable quantitative continue
quant_var = tips["total_bill"]
# Histogramme
sns.histplot(x=quant_var,kde=True)
plt.title("Histogramme de la variable le montant total de la facture")
plt.xlabel("Valeur")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# ### Courbe de densité KDE

# %%
# KDE plot
sns.kdeplot(x=quant_var)
plt.title("KDE plot de la variable le montant total de la facture")
plt.xlabel("Valeur")
plt.ylabel("Densité")
plt.show()

# %%
### Boite à moustache (Box plot)
# Boite à moustâche
# Diagramme en boîte
sns.boxplot(x=quant_var)
plt.title("Diagramme en boîte de lla variable le montant total de la facture")
plt.xlabel("Valeur")
plt.show()
